# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
dat = np.random.normal(0,1,500)

# %%
#visualize
plt.plot(dat)

# %%
plt.hist(dat, color = 'lightblue', edgecolor = 'black')
# Out:
# (array([  8.,  16.,  39.,  96., 113., 124.,  68.,  28.,   6.,   2.]),
#  array([-2.94927053, -2.3325284 , -1.71578627, -1.09904414, -0.48230201,
#          0.13444013,  0.75118226,  1.36792439,  1.98466652,  2.60140865,
#          3.21815078]),
#  <BarContainer object of 10 artists>)

# %%
plot_acf(dat, lags = 40);
